# %% [markdown]
# ## Library test

# %%
import sys
import os
sys.path.append("../src")
from utils import *
from ml_utils import *
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %%
test_dir = "../data/test/img"
os.makedirs(test_dir, exist_ok=True)

test_df = get_random_data(test_dir, 100, is_test=True)
test_df.head()
# Out:
# This function execute on test mode(automatically changes to num_loop=5).
#   0%|          | 0/5 [00:00<?, ?it/s]
#            id                                    asset.image_url  \
# 0  1537215539  https://lh3.googleusercontent.com/UyURBsV1Ed0f...
# 1  1537215538  https://lh3.googleusercontent.com/caTQs_45fLiU...
# 2  1537215536  https://lh3.googleusercontent.com/7MMfqz5OoGmK...
# 3  1537215535  https://lh3.googleusercontent.com/6M4FuEXJIt3n...
# 4  1537215534  https://lh3.googleusercontent.com/3wGoYULwUNLP...
#
#             base_price                  current_price  \
# 0    38000000000000000  38000000000000000.00000000000
# 1   819100000000000000  819100000000000000.0000000000
# 2   819100000000000000  819100000000000000.0000000000
# 3  2423599999999997300  2423599999999997300.000000000
# 4   374600000000000000  374600000000000000.0000000000
#
#                                 payment_token quantity asset.num_sales  \
# 0  0x0000000000000000000000000000000000000000        1               0
# 1  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               1
# 2  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               2
# 3  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               0
# 4  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               0
#
#    asset.id                                     asset.token_id  \
# 0  80335842  2300538991603141949549706883158928800990063278...
# 1  72367307                                               2580
# 2  72369189                                               3578
# 3  23309510                                              11093
# 4  61374139                                                514
#
#   asset_contract.name                asset.asset_contract.address  \
# 0                None  0x495f947276749ce646f68ac8c248420045cb7b5e
# 1                None  0x11450058d796b02eb53e65374be59cff65d3fe7f
# 2                None  0x11450058d796b02eb53e65374be59cff65d3fe7f
# 3                None  0x7bd29408f11d2bfc23c34f18275bbf23bb716bc7
# 4                None  0x5754f44bc96f9f0fe1a568253452a3f40f5e9f59
#
#   asset.asset_contract.asset_contract_type  asset.asset_contract.owner  \
# 0                            semi-fungible                    102384.0
# 1                             non-fungible                  54865231.0
# 2                             non-fungible                  54865231.0
# 3                             non-fungible                         NaN
# 4                             non-fungible                  85610008.0
#
#   image_id
# 0    0.png
# 1    1.png
# 2    2.png
# 3    3.png
# 4    4.png

# %% [markdown]
# #### テストでないものが動くことの確認

# %%
test_df = get_random_data(test_dir, 10)
test_df.head()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#            id                                    asset.image_url  \
# 0  1537282981  https://lh3.googleusercontent.com/geruSdR8Aj3o...
# 1  1537282980  https://lh3.googleusercontent.com/w6AEmqN2NvtY...
# 2  1537282979  https://lh3.googleusercontent.com/BddsT8PIBFPQ...
# 3  1537282978  https://lh3.googleusercontent.com/zkYPrOmRyvyi...
# 4  1537282977  https://lh3.googleusercontent.com/TdKbucgwtghI...
#
#            base_price                  current_price  \
# 0  214800000000000000  214800000000000000.0000000000
# 1  315800000000000000  315800000000000000.0000000000
# 2   69000000000000000  69000000000000000.00000000000
# 3  250000000000000000  250000000000000000.0000000000
# 4  251000000000000000  251000000000000000.0000000000
#
#                                 payment_token quantity asset.num_sales  \
# 0  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               2
# 1  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               1
# 2  0x0000000000000000000000000000000000000000        1               0
# 3  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               2
# 4  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               0
#
#    asset.id                                     asset.token_id  \
# 0  19915051                                               3738
# 1  83574520                                               9726
# 2  74306667  3408548560580985823464505673624610083362790836...
# 3  46650257                                               6479
# 4  46414062                                               2004
#
#   asset_contract.name                asset.asset_contract.address  \
# 0                None  0x97ca7fe0b0288f5eb85f386fed876618fb9b8ab8
# 1                None  0xf1268733c6fb05ef6be9cf23d24436dcd6e0b35e
# 2                None  0x495f947276749ce646f68ac8c248420045cb7b5e
# 3                None  0x90ca8a3eb2574f937f514749ce619fdcca187d45
# 4                None  0x90ca8a3eb2574f937f514749ce619fdcca187d45
#
#   asset.asset_contract.asset_contract_type  asset.asset_contract.owner  \
# 0                             non-fungible                  24360613.0
# 1                             non-fungible                  94822732.0
# 2                            semi-fungible                    102384.0
# 3                             non-fungible                  75372756.0
# 4                             non-fungible                  75372756.0
#
#   image_id
# 0    0.png
# 1    1.png
# 2    2.png
# 3    3.png
# 4    4.png

# %% [markdown]
# ### get_collection_data
#
# #### テストが動くことの確認

# %%
target_collections = ['cryptopunks', 'boredapeyachtclub',
                      'doodles-official', 'jungle-freaks-by-trosley',
                      'kaiju-kingz', 'galaxyeggs9999',
                      'sneaky-vampire-syndicate',
                      'axie', 'cyberkongz']

test_df = get_collection_data(test_dir, target_collections,
                              is_test=True)
test_df.head()
# Out:
# This function execute on test mode.
# Automatically set target_collections:
# ['cryptopunks', 'boredapeyachtclub', 'doodles-official']
# cryptopunks:   0%|          | 0/10 [00:00<?, ?it/s]
# boredapeyachtclub:   0%|          | 0/10 [00:00<?, ?it/s]
# doodles-official:   0%|          | 0/10 [00:00<?, ?it/s]
# error count: 0
# error collection: []
#        id num_sales                                          image_url  \
# 0  178786         1  https://lh3.googleusercontent.com/5vRk0wgiWmQh...
# 1  527323         5  https://lh3.googleusercontent.com/ZKAyGl7xFS9T...
# 2  179306         8  https://lh3.googleusercontent.com/BxIUpLH1_fAL...
# 3  179584         5  https://lh3.googleusercontent.com/lLD-2mJ8O9W4...
# 4  177748         3  https://lh3.googleusercontent.com/Jr2djjreawlu...
#
#   asset_contract.name                               owner.address  \
# 0         CryptoPunks  0x7eb413211a9de1cd2fe8b8bb6055636c43f7d206
# 1         CryptoPunks  0x3284a7c3c5a20bdd33f28d5c2bcfccc2c2514049
# 2         CryptoPunks  0x3284a7c3c5a20bdd33f28d5c2bcfccc2c2514049
# 3         CryptoPunks  0x32beafcd6bffda7df6111f6ceb12884c919534fa
# 4         CryptoPunks  0xdfa6e4f558653a497de28d04ddccba3458c088fc
#
#   last_sale.quantity  last_sale.total_price image_id
# 0                  1  387000000000000000000    0.png
# 1                  1   82950000000000000000    1.png
# 2                  1   79420000000000000000    2.png
# 3                  1   77770000000000000000    3.png
# 4                  1  500000000000000000000    4.png

# %% [markdown]
# #### 本番が動くことの確認

# %%
target_collections = ['cryptopunks', 'boredapeyachtclub',
                      'doodles-official', 'jungle-freaks-by-trosley',
                      'kaiju-kingz']

test_df = get_collection_data(test_dir, target_collections)
test_df.head()
# Out:
# cryptopunks:   0%|          | 0/10 [00:00<?, ?it/s]
# boredapeyachtclub:   0%|          | 0/10 [00:00<?, ?it/s]
# doodles-official:   0%|          | 0/10 [00:00<?, ?it/s]
# jungle-freaks-by-trosley:   0%|          | 0/10 [00:00<?, ?it/s]
# kaiju-kingz:   0%|          | 0/10 [00:00<?, ?it/s]
# error count: 0
# error collection: []
#        id num_sales                                          image_url  \
# 0  180090         1  https://lh3.googleusercontent.com/ysJjPNkxM92g...
# 1  178786         1  https://lh3.googleusercontent.com/5vRk0wgiWmQh...
# 2  527323         5  https://lh3.googleusercontent.com/ZKAyGl7xFS9T...
# 3  179306         8  https://lh3.googleusercontent.com/BxIUpLH1_fAL...
# 4  179584         5  https://lh3.googleusercontent.com/lLD-2mJ8O9W4...
#
#   asset_contract.name                               owner.address  \
# 0         CryptoPunks  0x4680cb63563472cac10236c07d288580d8d7b52a
# 1         CryptoPunks  0x7eb413211a9de1cd2fe8b8bb6055636c43f7d206
# 2         CryptoPunks  0x3284a7c3c5a20bdd33f28d5c2bcfccc2c2514049
# 3         CryptoPunks  0x3284a7c3c5a20bdd33f28d5c2bcfccc2c2514049
# 4         CryptoPunks  0x32beafcd6bffda7df6111f6ceb12884c919534fa
#
#   last_sale.quantity  last_sale.total_price image_id
# 0                  1   95000000000000000000    0.png
# 1                  1  387000000000000000000    1.png
# 2                  1   82950000000000000000    2.png
# 3                  1   79420000000000000000    3.png
# 4                  1   77770000000000000000    4.png

# %%
df = pd.read_csv("../data/taskA/table/asset_data.csv")
train_df, test_df = collection_validation(df, 'CryptoPunks')

# %%
train_df
# Out:
#            id  num_sales                                          image_url  \
# 0    23143058          7  https://lh3.googleusercontent.com/_fv_ZYnkIrnV...
# 1    23126079          3  https://lh3.googleusercontent.com/LrzCKWwMx_Or...
# 2    23143663          9  https://lh3.googleusercontent.com/CnukVYx0etu0...
# 3    23135823          2  https://lh3.googleusercontent.com/PeZTYLztECuf...
# 4    23142631          1  https://lh3.googleusercontent.com/5X8PWOz6ZN8X...
# ..        ...        ...                                                ...
# 995  74412264          1  https://lh3.googleusercontent.com/UCyrseZWGC1Y...
# 996  74054272          2  https://lh3.googleusercontent.com/tXjFG_N3Zbag...
# 997  74041943          2  https://lh3.googleusercontent.com/fM42rg9wzanD...
# 998  74058603          4  https://lh3.googleusercontent.com/quoXz5utPX3D...
# 999  74413519          3  https://lh3.googleusercontent.com/ezjem-UvhzX7...
#
#     asset_contract.name                               owner.address  \
# 0     BoredApeYachtClub  0x74f87893d8fdc52a99062d93e4769d5254bff754
# 1     BoredApeYachtClub  0x012b38ccb3ae97a32cd24088bf9426d4ee5442d3
# 2     BoredApeYachtClub  0xc5668475f3f02b7ce49defd09547ad19be1dcefa
# 3     BoredApeYachtClub  0xeb534880006bf1d21760c23e3f21bc374792069b
# 4     BoredApeYachtClub  0x4affe16d35143db85027c05d97f56ebdc668347e
# ..                  ...                                         ...
# 995             Doodles  0x03fba2e6f1c1dd10eb4e49e93c57ed84a527f532
# 996             Doodles  0x13eee41d67b8d99e11174161d72cf8ccd194458c
# 997             Doodles  0xf45b2b7686d38a435e6158296f0f95041ab163d9
# 998             Doodles  0x38746f87fe26ff44367385fc9ad0823c2b94861f
# 999             Doodles  0xc456eee9b43023de3003e0aa5cae3245559f2e09
#
#      last_sale.quantity last_sale.total_price  image_id
# 0                     1  36000000000000000000   500.png
# 1                     1  40000000000000000000   501.png
# 2                     1  35000000000000000000   502.png
# 3                     1  42000000000000000000   503.png
# 4                     1  31000000000000000000   504.png
# ..                  ...                   ...       ...
# 995                   1   1190000000000000000  1495.png
# 996                   1    984000000000000000  1496.png
# 997                   1   1000000000000000000  1497.png
# 998                   1    990000000000000000  1498.png
# 999                   1   2400000000000000000  1499.png
#
# [1000 rows x 8 columns]

# %%
test_df
# Out:
#          id  num_sales                                          image_url  \
# 0    179998          7  https://lh3.googleusercontent.com/AiYfz4_FMQHT...
# 1    525555          1  https://lh3.googleusercontent.com/-MBWIEP57pni...
# 2    525842          3  https://lh3.googleusercontent.com/cJe3EqjdQb1X...
# 3    526735          1  https://lh3.googleusercontent.com/aovarGyvxWTm...
# 4    530099          4  https://lh3.googleusercontent.com/9H7tfskqjBRS...
# ..      ...        ...                                                ...
# 495  529035          1  https://lh3.googleusercontent.com/dAShebSD5Wth...
# 496  178673          6  https://lh3.googleusercontent.com/MX9EYV4p2aNj...
# 497  178329          1  https://lh3.googleusercontent.com/CTY4D7sbxmbE...
# 498  527544          4  https://lh3.googleusercontent.com/p_oPTZkePf7X...
# 499  527021          9  https://lh3.googleusercontent.com/6pW_kCkpdagy...
#
#     asset_contract.name                               owner.address  \
# 0           CryptoPunks  0x1919db36ca2fa2e15f9000fd9cdc2edcf863e685
# 1           CryptoPunks  0xe16cbb857388575cf80c23c058ddae2f73785a25
# 2           CryptoPunks  0x79782b0ae9b71cff36bb32b4ef0935fd3c190350
# 3           CryptoPunks  0x977089ca5b701e09637768cde651b94855d13eab
# 4           CryptoPunks  0xc2e26de7dd36de8f54b3e66ecba06f9feb84ef2c
# ..                  ...                                         ...
# 495         CryptoPunks  0x8b6fb9fd6a29960c7d7a376158575278d1a6f8ba
# 496         CryptoPunks  0x5c407c4ffffa7fb1d872c8553b84b5f03db79c86
# 497         CryptoPunks  0x485248150969e92b460508b5c8c7e866ed7fae75
# 498         CryptoPunks  0xbf8f78b19307062aa89beadf8d38f6e2bb33e795
# 499         CryptoPunks  0xe9aa4441bab6534bee133b07dfe7d15a3a431fcc
#
#      last_sale.quantity  last_sale.total_price image_id
# 0                     1   85000000000000000020    0.png
# 1                     1  102970000000000000000    1.png
# 2                     1  124990000000000000000    2.png
# 3                     1  103000000000000000000    3.png
# 4                     1  199000000000000000000    4.png
# ..                  ...                    ...      ...
# 495                   1  167500000000000000000  495.png
# 496                   1  269000000000000000000  496.png
# 497                   1  179000000000000000000  497.png
# 498                   1  136000000000000000000  498.png
# 499                   1  124950000000000000000  499.png
#
# [500 rows x 8 columns]

# %%
train_df['asset_contract.name'].unique()
# Out:
# array(['BoredApeYachtClub', 'Doodles'], dtype=object)

# %%
test_df['asset_contract.name'].unique()
# Out:
# array(['CryptoPunks'], dtype=object)

# %% [markdown]
# ### 本番環境で入力された情報からデータを取得する関数
# - 既存のNFTの今後の値段を予測するために用いる予定．
# - 取得したデータからモデルに入力するデータを抽出する．
# - limitを上限までしても取得できるデータが制限されている（直近のoffer価格）．

# %%
def get_data(asset_contract_address: str, token_id: str):
    """
    Get the asset data.

    Parameters
    ----------
    asset_contract_address : str
        The string of asset contract address.
    token_id : str
        The string of token id.

    Returns
    -------
    orders_df : pd.DataFrame
        The dataframe of asset data.
    """

    if type(token_id) != str:
        token_id = str(token_id)
    url = f"https://api.opensea.io/wyvern/v1/orders?asset_contract_address={asset_contract_address}&bundled=false&include_bundled=false&include_invalid=false&token_id={token_id}&limit=50&offset=0"
    headers = {"Accept": "application/json"}

    response = requests.request("GET", url, headers=headers)

    data = response.json()
    orders_df = pd.json_normalize(data['orders'])

    return orders_df

# %%
df = get_data('0x0c2e57efddba8c768147d1fdf9176a0a6ebd5d83', '2790')
df
# Out:
#            id asset_bundle                created_date         closing_date  \
# 0  1540142334         None  2021-11-09T09:48:46.692530  2021-11-09T13:48:46
# 1  1539983266         None  2021-11-09T09:32:33.251623  2021-11-09T11:02:28
# 2  1539498203         None  2021-11-09T08:39:32.337937  2021-11-09T21:09:00
# 3  1537981780         None  2021-11-09T05:52:59.353560  2021-11-09T17:52:57
# 4  1531747267         None  2021-11-08T19:13:44.932891  2021-11-09T19:13:37
#
#    closing_extendable  expiration_time  listing_time  \
# 0               False       1636465726    1636451226
# 1               False       1636455748    1636450348
# 2               False       1636492140    1636447069
# 3               False       1636480377    1636437078
# 4               False       1636485217    1636398722
#
#                                           order_hash  \
# 0  0xbdc140fc5d35d960bac8503eb6e4fec11ec9789ca407...
# 1  0x6351d44b1afbd5cd7f467e5999b2937d751f07288f40...
# 2  0xa168959c95923fd12e79d4531fef735e0aa686bd3711...
# 3  0x335a1c30c75ecf1ce8ee80c45379775c93616b97a587...
# 4  0xc726aa83a4dcb85a9d2eb200fe4fafdacbd063230fb7...
#
#                                      exchange                  current_price  \
# 0  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b  890500000000000000.0000000000
# 1  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b  2110200000000000000.000000000
# 2  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b  2100000000000000000.000000000
# 3  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b  1500000000000000000.000000000
# 4  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b  2619000000000000000.000000000
#
#    ...                       fee_recipient.address fee_recipient.config  \
# 0  ...  0x5b3256965e7c3cf26e11fcaf296dfc8807c01073             verified
# 1  ...  0x5b3256965e7c3cf26e11fcaf296dfc8807c01073             verified
# 2  ...  0x5b3256965e7c3cf26e11fcaf296dfc8807c01073             verified
# 3  ...  0x5b3256965e7c3cf26e11fcaf296dfc8807c01073             verified
# 4  ...  0x5b3256965e7c3cf26e11fcaf296dfc8807c01073             verified
#
#   payment_token_contract.id payment_token_contract.symbol  \
# 0                         2                          WETH
# 1                         2                          WETH
# 2                         2                          WETH
# 3                         2                          WETH
# 4                         2                          WETH
#
#                payment_token_contract.address  \
# 0  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
#                     payment_token_contract.image_url  \
# 0  https://storage.opensea.io/files/accae6b6fb388...
# 1  https://storage.opensea.io/files/accae6b6fb388...
# 2  https://storage.opensea.io/files/accae6b6fb388...
# 3  https://storage.opensea.io/files/accae6b6fb388...
# 4  https://storage.opensea.io/files/accae6b6fb388...
#
#   payment_token_contract.name  payment_token_contract.decimals  \
# 0               Wrapped Ether                               18
# 1               Wrapped Ether                               18
# 2               Wrapped Ether                               18
# 3               Wrapped Ether                               18
# 4               Wrapped Ether                               18
#
#    payment_token_contract.eth_price  payment_token_contract.usd_price
# 0                 1.000000000000000           4819.569999999999709000
# 1                 1.000000000000000           4819.569999999999709000
# 2                 1.000000000000000           4819.569999999999709000
# 3                 1.000000000000000           4819.569999999999709000
# 4                 1.000000000000000           4819.569999999999709000
#
# [5 rows x 135 columns]

# %%
df = get_data('0x97ca7fe0b0288f5eb85f386fed876618fb9b8ab8', 3738)
df
# Out:
#            id asset_bundle                created_date         closing_date  \
# 0  1540003572         None  2021-11-09T09:34:34.500061  2021-11-09T13:34:29
# 1  1539208650         None  2021-11-09T08:06:54.236790  2021-11-09T12:06:53
# 2  1538223874         None  2021-11-09T06:20:19.846033  2021-11-09T10:20:15
# 3   385438647         None  2021-08-12T19:48:12.672581                 None
#
#    closing_extendable  expiration_time  listing_time  \
# 0               False       1636464869    1636450369
# 1               False       1636459613    1636445113
# 2               False       1636453215    1636438715
# 3               False                0    1628797589
#
#                                           order_hash  \
# 0  0xd10cf6f4d3b4795e4c82ffc6cd2d5c3132b6f3616f6d...
# 1  0xc9a594de5a69a6e0275edac9fe3cfd35a194a68d17f0...
# 2  0xfbd7a8105d977bfac0ec1d2fd6dc4553d2e054d79916...
# 3  0x97265d69ce6466347bb9c672339ecc869728769ffae6...
#
#                                      exchange                  current_price  \
# 0  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b  214800000000000000.0000000000
# 1  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b  214800000000000000.0000000000
# 2  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b  214800000000000000.0000000000
# 3  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b              60000000000000000
#
#    ...                       fee_recipient.address fee_recipient.config  \
# 0  ...  0x5b3256965e7c3cf26e11fcaf296dfc8807c01073             verified
# 1  ...  0x5b3256965e7c3cf26e11fcaf296dfc8807c01073             verified
# 2  ...  0x5b3256965e7c3cf26e11fcaf296dfc8807c01073             verified
# 3  ...  0x5b3256965e7c3cf26e11fcaf296dfc8807c01073             verified
#
#   payment_token_contract.id payment_token_contract.symbol  \
# 0                         2                          WETH
# 1                         2                          WETH
# 2                         2                          WETH
# 3                         2                          WETH
#
#                payment_token_contract.address  \
# 0  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
#                     payment_token_contract.image_url  \
# 0  https://storage.opensea.io/files/accae6b6fb388...
# 1  https://storage.opensea.io/files/accae6b6fb388...
# 2  https://storage.opensea.io/files/accae6b6fb388...
# 3  https://storage.opensea.io/files/accae6b6fb388...
#
#   payment_token_contract.name  payment_token_contract.decimals  \
# 0               Wrapped Ether                               18
# 1               Wrapped Ether                               18
# 2               Wrapped Ether                               18
# 3               Wrapped Ether                               18
#
#    payment_token_contract.eth_price  payment_token_contract.usd_price
# 0                 1.000000000000000           4819.569999999999709000
# 1                 1.000000000000000           4819.569999999999709000
# 2                 1.000000000000000           4819.569999999999709000
# 3                 1.000000000000000           4819.569999999999709000
#
# [4 rows x 135 columns]
