# %% [markdown]
# # 画像データの寄与が大きいのかを確認する．
# - TargetEncodingした特徴量のみで線型回帰，lgbmで予測を行う．
# - その結果と画像のみの結果，標準偏差と比較を行う．

# %%
import os
import gc
import warnings

import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
import lightgbm as lgb
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')

# %%
DATAPATH = "../data/taskA/table"
df = pd.read_csv(os.path.join(DATAPATH, "asset_data.csv"))

df = df.rename(columns={"last_sale.total_price": "target"})
df['target'] = df['target'].astype(float) * 1e-18
df = df.query('target > 0').reset_index(drop=True)
df['target'] = df['target'].apply(lambda x: np.log1p(x))
display(df.head())
print(f"data shape: {df.shape}")
# Out:
#        id token_id  num_sales background_color  \
# 0  527189     3604          3              NaN
# 1  528119     5108          1              NaN
# 2  527733     4503          1              NaN
# 3  176535     6729          1              NaN
# 4  179178     4313          4              NaN
#
#                                            image_url  \
# 0  https://lh3.googleusercontent.com/F29AWc3Qgx3Q...
# 1  https://lh3.googleusercontent.com/CLeVgaNXAR3y...
# 2  https://lh3.googleusercontent.com/uXSp3edvlFtO...
# 3  https://lh3.googleusercontent.com/hQ0qO_Kzf94W...
# 4  https://lh3.googleusercontent.com/xJeddtlpPc1k...
#
#                                    image_preview_url  \
# 0  https://lh3.googleusercontent.com/F29AWc3Qgx3Q...
# 1  https://lh3.googleusercontent.com/CLeVgaNXAR3y...
# 2  https://lh3.googleusercontent.com/uXSp3edvlFtO...
# 3  https://lh3.googleusercontent.com/hQ0qO_Kzf94W...
# 4  https://lh3.googleusercontent.com/xJeddtlpPc1k...
#
#                                  image_thumbnail_url  \
# 0  https://lh3.googleusercontent.com/F29AWc3Qgx3Q...
# 1  https://lh3.googleusercontent.com/CLeVgaNXAR3y...
# 2  https://lh3.googleusercontent.com/uXSp3edvlFtO...
# 3  https://lh3.googleusercontent.com/hQ0qO_Kzf94W...
# 4  https://lh3.googleusercontent.com/xJeddtlpPc1k...
#
#                                   image_original_url animation_url  \
# 0  https://www.larvalabs.com/cryptopunks/cryptopu...           NaN
# 1  https://www.larvalabs.com/cryptopunks/cryptopu...           NaN
# 2  https://www.larvalabs.com/cryptopunks/cryptopu...           NaN
# 3  https://www.larvalabs.com/cryptopunks/cryptopu...           NaN
# 4  https://www.larvalabs.com/cryptopunks/cryptopu...           NaN
#
#   animation_original_url  ... last_sale.transaction.transaction_index  \
# 0                    NaN  ...                                     164
# 1                    NaN  ...                                      36
# 2                    NaN  ...                                     251
# 3                    NaN  ...                                      30
# 4                    NaN  ...                                      34
#
#        last_sale.created_date last_sale.quantity  \
# 0  2021-11-12T15:19:23.231230                  1
# 1  2021-11-12T07:46:09.630431                  1
# 2  2021-11-12T01:01:22.486461                  1
# 3  2021-11-12T00:31:25.335608                  1
# 4  2021-11-11T18:00:22.265147                  1
#
#   last_sale.transaction.from_account.user.username  owner.user.username  \
# 0                                              NaN                  NaN
# 1                                       Cool-Punks                  NaN
# 2                                              NaN                  NaN
# 3                                       Cool-Punks                  NaN
# 4                                              NaN                  NaN
#
#   last_sale.transaction.to_account.user.username creator.user.username  \
# 0                                            NaN                   NaN
# 1                                            NaN                   NaN
# 2                                            NaN                   NaN
# 3                                            NaN                   NaN
# 4                                            NaN                   NaN
#
#   creator  collection.display_data.images  image_id
# 0     NaN                             NaN     0.png
# 1     NaN                             NaN     1.png
# 2     NaN                             NaN     2.png
# 3     NaN                             NaN     3.png
# 4     NaN                             NaN     5.png
#
# [5 rows x 121 columns]
# data shape: (21747, 121)

# %% [markdown]
# ## 比較用の標準偏差を算出

# %%
std = df.groupby(['collection.name'])['target'].std()
df['target_std'] = df['collection.name'].map(std)
df
# Out:
#              id token_id  num_sales background_color  \
# 0        527189     3604          3              NaN
# 1        528119     5108          1              NaN
# 2        527733     4503          1              NaN
# 3        176535     6729          1              NaN
# 4        179178     4313          4              NaN
# ...         ...      ...        ...              ...
# 21742  69833705     5899          1              NaN
# 21743  69778852     4550          1              NaN
# 21744  69747647     2311          2              NaN
# 21745  69864384     7391          2              NaN
# 21746  69870290     7798          1              NaN
#
#                                                image_url  \
# 0      https://lh3.googleusercontent.com/F29AWc3Qgx3Q...
# 1      https://lh3.googleusercontent.com/CLeVgaNXAR3y...
# 2      https://lh3.googleusercontent.com/uXSp3edvlFtO...
# 3      https://lh3.googleusercontent.com/hQ0qO_Kzf94W...
# 4      https://lh3.googleusercontent.com/xJeddtlpPc1k...
# ...                                                  ...
# 21742  https://lh3.googleusercontent.com/7HBOUJgyf65i...
# 21743  https://lh3.googleusercontent.com/lNQrfDhiXlls...
# 21744  https://lh3.googleusercontent.com/Zp9xXj8yfxDr...
# 21745  https://lh3.googleusercontent.com/5ROEuPyJS0AB...
# 21746  https://lh3.googleusercontent.com/E5Bb-tHawJFb...
#
#                                        image_preview_url  \
# 0      https://lh3.googleusercontent.com/F29AWc3Qgx3Q...
# 1      https://lh3.googleusercontent.com/CLeVgaNXAR3y...
# 2      https://lh3.googleusercontent.com/uXSp3edvlFtO...
# 3      https://lh3.googleusercontent.com/hQ0qO_Kzf94W...
# 4      https://lh3.googleusercontent.com/xJeddtlpPc1k...
# ...                                                  ...
# 21742  https://lh3.googleusercontent.com/7HBOUJgyf65i...
# 21743  https://lh3.googleusercontent.com/lNQrfDhiXlls...
# 21744  https://lh3.googleusercontent.com/Zp9xXj8yfxDr...
# 21745  https://lh3.googleusercontent.com/5ROEuPyJS0AB...
# 21746  https://lh3.googleusercontent.com/E5Bb-tHawJFb...
#
#                                      image_thumbnail_url  \
# 0      https://lh3.googleusercontent.com/F29AWc3Qgx3Q...
# 1      https://lh3.googleusercontent.com/CLeVgaNXAR3y...
# 2      https://lh3.googleusercontent.com/uXSp3edvlFtO...
# 3      https://lh3.googleusercontent.com/hQ0qO_Kzf94W...
# 4      https://lh3.googleusercontent.com/xJeddtlpPc1k...
# ...                                                  ...
# 21742  https://lh3.googleusercontent.com/7HBOUJgyf65i...
# 21743  https://lh3.googleusercontent.com/lNQrfDhiXlls...
# 21744  https://lh3.googleusercontent.com/Zp9xXj8yfxDr...
# 21745  https://lh3.googleusercontent.com/5ROEuPyJS0AB...
# 21746  https://lh3.googleusercontent.com/E5Bb-tHawJFb...
#
#                                       image_original_url animation_url  \
# 0      https://www.larvalabs.com/cryptopunks/cryptopu...           NaN
# 1      https://www.larvalabs.com/cryptopunks/cryptopu...           NaN
# 2      https://www.larvalabs.com/cryptopunks/cryptopu...           NaN
# 3      https://www.larvalabs.com/cryptopunks/cryptopu...           NaN
# 4      https://www.larvalabs.com/cryptopunks/cryptopu...           NaN
# ...                                                  ...           ...
# 21742  https://ipfs.io/ipfs/QmdTuijJHYpkZvpJHPJex1bQN...           NaN
# 21743  https://ipfs.io/ipfs/QmTMi8MBEFC61x7dpeBgMdkMn...           NaN
# 21744  https://ipfs.io/ipfs/QmdA48nHNXo84Rzaf96w9iCDx...           NaN
# 21745  https://ipfs.io/ipfs/Qmc1v7vnXpPsuxphNufFDXK8d...           NaN
# 21746  https://ipfs.io/ipfs/QmW11TakUtdw22Mhpme41peQ3...           NaN
#
#       animation_original_url  ...      last_sale.created_date  \
# 0                        NaN  ...  2021-11-12T15:19:23.231230
# 1                        NaN  ...  2021-11-12T07:46:09.630431
# 2                        NaN  ...  2021-11-12T01:01:22.486461
# 3                        NaN  ...  2021-11-12T00:31:25.335608
# 4                        NaN  ...  2021-11-11T18:00:22.265147
# ...                      ...  ...                         ...
# 21742                    NaN  ...  2021-11-06T16:57:48.917500
# 21743                    NaN  ...  2021-11-06T16:40:42.496175
# 21744                    NaN  ...  2021-11-06T16:31:24.084151
# 21745                    NaN  ...  2021-11-06T16:17:43.655307
# 21746                    NaN  ...  2021-11-06T16:01:38.274175
#
#       last_sale.quantity last_sale.transaction.from_account.user.username  \
# 0                      1                                              NaN
# 1                      1                                       Cool-Punks
# 2                      1                                              NaN
# 3                      1                                       Cool-Punks
# 4                      1                                              NaN
# ...                  ...                                              ...
# 21742                  1                                           iamgub
# 21743                  1                                   el_collectooor
# 21744                  1                                              NaN
# 21745                  1                                              NaN
# 21746                  1                                        SharpLedg
#
#       owner.user.username  last_sale.transaction.to_account.user.username  \
# 0                     NaN                                             NaN
# 1                     NaN                                             NaN
# 2                     NaN                                             NaN
# 3                     NaN                                             NaN
# 4                     NaN                                             NaN
# ...                   ...                                             ...
# 21742              iamgub                                  OpenSea-Orders
# 21743         BurnAddress                                  OpenSea-Orders
# 21744         BurnAddress                                  OpenSea-Orders
# 21745         BurnAddress                                  OpenSea-Orders
# 21746           SharpLedg                                  OpenSea-Orders
#
#       creator.user.username creator collection.display_data.images   image_id  \
# 0                       NaN     NaN                            NaN      0.png
# 1                       NaN     NaN                            NaN      1.png
# 2                       NaN     NaN                            NaN      2.png
# 3                       NaN     NaN                            NaN      3.png
# 4                       NaN     NaN                            NaN      5.png
# ...                     ...     ...                            ...        ...
# 21742                Eponym     NaN                            NaN  21754.png
# 21743                Eponym     NaN                            NaN  21755.png
# 21744                Eponym     NaN                            NaN  21756.png
# 21745                Eponym     NaN                            NaN  21757.png
# 21746                Eponym     NaN                            NaN  21758.png
#
#        target_std
# 0        0.503242
# 1        0.503242
# 2        0.503242
# 3        0.503242
# 4        0.503242
# ...           ...
# 21742    0.069797
# 21743    0.069797
# 21744    0.069797
# 21745    0.069797
# 21746    0.069797
#
# [21747 rows x 122 columns]

# %%
std
# Out:
# collection.name
# Angry Apes United               0.006908
# Art Wars | AW                   0.244090
# BearXLabs                       0.115839
# Bears Deluxe                    0.142489
# Bored Ape Yacht Club            0.450446
# Chain Runners                   0.149483
# Chromie Squiggle by Snowfro     0.495147
# Cool Cats NFT                   0.221487
# Cosmic Labs                     0.111132
# CrypToadz by GREMPLIN           0.261591
# CryptoPunks                     0.503242
# CyberKongz                      0.830541
# Decentraland                    3.788774
# Desperate ApeWives              0.221327
# Divine Anarchy                  0.201517
# Doodles                         0.225762
# Edifice by Ben Kovach           0.288578
# Emblem Vault [Ethereum]         0.755248
# Eponym by ART AI                0.069797
# Fat Ape Club                    0.166158
# Furballs.com Official           0.085911
# Hor1zon Troopers                0.206734
# JUNGLE FREAKS BY TROSLEY        0.191087
# Kaiju Kingz                     0.355589
# LOSTPOETS                       0.310503
# Lazy Lions                      0.181369
# Meebits                         0.301200
# MekaVerse                       0.273255
# Mutant Ape Yacht Club           0.178795
# MutantCats                      0.100152
# Neo Tokyo Identities            0.418610
# Neo Tokyo Part 2 Vault Cards    0.608894
# Neo Tokyo Part 3 Item Caches    0.465960
# PUNKS Comic                     0.369300
# Parallel Alpha                  1.545474
# Party Ape | Billionaire Club    0.219557
# Playboy Rabbitars Official      0.243390
# Sipherian Flash                 0.243022
# SuperFarm Genesis Series        0.290950
# THE REAL GOAT SOCIETY           0.163046
# THE SHIBOSHIS                   2.756224
# The Doge Pound                  0.124685
# The Sandbox                     2.386731
# Treeverse                       0.085823
# VeeFriends                      0.377835
# Vox Collectibles                0.353711
# World of Women                  0.298015
# Name: target, dtype: float64

# %% [markdown]
# ## CVを用いてスコアを算出する．

# %%
def train_model(df, model='linear', n_splits=4):
    kf = KFold(n_splits=n_splits, random_state=6174, shuffle=True)
    rmse_scores = np.array([])
    mae_scores = np.array([])
    for train_idx, val_idx in kf.split(df):
        train_X, val_X = df.iloc[train_idx], df.iloc[val_idx]
        train_y, val_y = df.loc[train_idx, 'target'].values, df.loc[val_idx, 'target'].values

        enc = train_X.groupby(["collection.name"])['target'].mean()
        train_X['target_encoding'] = train_X['collection.name'].map(enc)
        val_X['target_encoding'] = val_X['collection.name'].map(enc)

        train_X = train_X['target_encoding'].values.reshape(-1, 1)
        val_X = val_X['target_encoding'].values.reshape(-1, 1)

        if model == 'linear':
            model = LinearRegression()
        elif model == 'lgb':
            model = lgb.LGBMRegressor()

        model.fit(train_X, train_y)
        pred = model.predict(val_X)
        rmse = np.sqrt(mean_squared_error(val_y, pred))
        mae = mean_absolute_error(val_y, pred)
        rmse_scores = np.append(rmse_scores, rmse)
        mae_scores = np.append(mae_scores, mae)

    print(f"RMSE score: {rmse_scores.mean()}")
    print(f"MAE score: {mae_scores.mean()}")

# %%
train_model(df)
# Out:
# RMSE score: 0.8102209382076688
# MAE score: 0.293336579754202

# %%
train_model(df, model='lgb')
# Out:
# RMSE score: 0.8102208478575466
# MAE score: 0.29333934042065035

# %%
print(f"Price std: {std.std()}")
# Out:
# Price std: 0.7214826744355846
