# %% [markdown]
# # Get data

# %%
import sys
import os
sys.path.append("../src")
from utils import *

pd.options.display.max_columns = 200

# %% [markdown]
# ## ディレクトリの作成

# %%
make_path = ["../data/taskA/img", "../data/taskA/table",
             "../data/taskB/img", "../data/taskB/table"]

for path in make_path:
    os.makedirs(path, exist_ok=True)

# %% [markdown]
# ### 有名collectionのデータ収集
#
# #### 例外発生時の処理について
# - 例外が発生しても処理を続けるように設定している．pramsによってデータ取得時にhttp error 500が発生する可能性が有り，paramを変えないと同様のエラーが発生する．そのときに例外発生し，通常は処理が止まるがデータ収集を効率的にするため処理を続ける．

# %%
collection_df = get_collection_data("../data/taskA/img", is_test=True)
collection_df.to_csv("../data/taskA/table/asset_data.csv", index=False)
collection_df
# Out:
# This function execute on test mode.
# Automatically set target_collections:
# ['cryptopunks', 'boredapeyachtclub', 'doodles-official']
# cryptopunks:   0%|          | 0/10 [00:00<?, ?it/s]
# boredapeyachtclub:   0%|          | 0/10 [00:00<?, ?it/s]
# doodles-official:   0%|          | 0/10 [00:00<?, ?it/s]
# error count: 0
# error collection: []
#             id num_sales                                          image_url  \
# 0       180081         7  https://lh3.googleusercontent.com/y3oCt__zuawn...
# 1       179359         8  https://lh3.googleusercontent.com/UkQO6T35v23e...
# 2       180090         1  https://lh3.googleusercontent.com/ysJjPNkxM92g...
# 3       178786         1  https://lh3.googleusercontent.com/5vRk0wgiWmQh...
# 4       527323         5  https://lh3.googleusercontent.com/ZKAyGl7xFS9T...
# ...        ...       ...                                                ...
# 1495  74057356         1  https://lh3.googleusercontent.com/GJFY-f90KPye...
# 1496  74139693         1  https://lh3.googleusercontent.com/n0z-zlmn8NXG...
# 1497  74044645         3  https://lh3.googleusercontent.com/y-_A1pI9E3zQ...
# 1498  74043776         4  https://lh3.googleusercontent.com/vjpaHoY---ff...
# 1499  74067584         3  https://lh3.googleusercontent.com/oGyHMYHucpnD...
#
#      asset_contract.name                               owner.address  \
# 0            CryptoPunks  0x53311150764f7eb2999022ed1aa5a8c17bb5fc57
# 1            CryptoPunks  0x5e4210e05368394e0820847c92b424bf37a0a5e8
# 2            CryptoPunks  0x4680cb63563472cac10236c07d288580d8d7b52a
# 3            CryptoPunks  0x7eb413211a9de1cd2fe8b8bb6055636c43f7d206
# 4            CryptoPunks  0x3284a7c3c5a20bdd33f28d5c2bcfccc2c2514049
# ...                  ...                                         ...
# 1495             Doodles  0x40f845e583b188b91d75528e1d21fb23595f2951
# 1496             Doodles  0x7260d0f2836e94f3b740afd475bd4a056d755be5
# 1497             Doodles  0xed50502c6d96b8ac09a508fc40928186390394b8
# 1498             Doodles  0x5685a0d411e88fdf99702189506540807c0fd4f0
# 1499             Doodles  0xee42cf807adf281877d1dfbfc7726bc9bc00c381
#
#      last_sale.quantity  last_sale.total_price  image_id
# 0                     1   85950000000000000000     0.png
# 1                     1   85000000000000000000     1.png
# 2                     1   95000000000000000000     2.png
# 3                     1  387000000000000000000     3.png
# 4                     1   82950000000000000000     4.png
# ...                 ...                    ...       ...
# 1495                  1    1000000000000000000  1495.png
# 1496                  1     989000000000000000  1496.png
# 1497                  1     987900000000000000  1497.png
# 1498                  1    1040000000000000000  1498.png
# 1499                  1    1400000000000000000  1499.png
#
# [1500 rows x 8 columns]

# %% [markdown]
# ### 様々なNFTのデータ収集
#
# #### 例外発生時の処理について
# - svgデータでアニメーション付きのものは画像として保存できないため，データから除外する．もし動画データに関しても予測をする場合は要検討．例外が発生した場合でもデータを収集するために処理を続けるようにする．

# %%
random_df = get_random_data("../data/taskB/img", is_test=True)
random_df.to_csv("../data/taskB/table/asset_data.csv", index=False)
random_df
# Out:
# This function execute on test mode(automatically changes to num_loop=5).
#   0%|          | 0/5 [00:00<?, ?it/s]
#              id                                    asset.image_url  \
# 0    1541252433  https://lh3.googleusercontent.com/s9-j3bQlOQB6...
# 1    1541252432  https://lh3.googleusercontent.com/-6xPdrvq9mGC...
# 2    1541252431  https://lh3.googleusercontent.com/lEnintb-gIZN...
# 3    1541252430  https://lh3.googleusercontent.com/R4GOOwluwDe5...
# 4    1541252429  https://lh3.googleusercontent.com/dNHv-0-UPZHs...
# ..          ...                                                ...
# 204  1541312930  https://lh3.googleusercontent.com/GH-AMY81oj3y...
# 205  1541312928  https://lh3.googleusercontent.com/oOkD3WDc42yz...
# 206  1541312927  https://lh3.googleusercontent.com/iJngdJvggoSS...
# 207  1541312926  https://storage.opensea.io/files/a1a46b8e4ae0f...
# 208  1541312925  https://lh3.googleusercontent.com/dtzgQ4CWKwXa...
#
#               base_price                  current_price  \
# 0    3405599999999999700  3405599999999999700.000000000
# 1     169300000000000000  169300000000000000.0000000000
# 2    3402900000000000000  3402900000000000000.000000000
# 3      11000000000000000  11000000000000000.00000000000
# 4    2808000000000000000  2808000000000000000.000000000
# ..                   ...                            ...
# 204   388500000000000000  388500000000000000.0000000000
# 205  2600000000000000000  2600000000000000000.000000000
# 206    76500000000000000  76500000000000000.00000000000
# 207   148600000000000000  148600000000000000.0000000000
# 208  2966500000000000000  2966500000000000000.000000000
#
#                                   payment_token quantity asset.num_sales  \
# 0    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               2
# 1    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               1
# 2    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               0
# 3    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               1
# 4    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               0
# ..                                          ...      ...             ...
# 204  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               1
# 205  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               3
# 206  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               1
# 207  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               0
# 208  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               0
#
#      asset.id                            asset.token_id asset_contract.name  \
# 0    42195000                                      2233                None
# 1    62816409                                      9290                None
# 2    42241907                                     16170                None
# 3    38847183                                      6529                None
# 4    42199004                                      4335                None
# ..        ...                                       ...                 ...
# 204  59721627                                      5339                None
# 205  23307248                                      1918                None
# 206  86426177  7826494439181584659657615970930668863950                None
# 207  69288257                                      2662                None
# 208  22149102                               22700070273                None
#
#                    asset.asset_contract.address  \
# 0    0x60e4d786628fea6478f785a6d7e704777c86a7c6
# 1    0x986aea67c7d6a15036e18678065eb663fc5be883
# 2    0x60e4d786628fea6478f785a6d7e704777c86a7c6
# 3    0x9c0ffc9088abeb2ea220d642218874639229fa7a
# 4    0x60e4d786628fea6478f785a6d7e704777c86a7c6
# ..                                          ...
# 204  0x12d2d1bed91c24f878f37e66bd829ce7197e4d14
# 205  0x7bd29408f11d2bfc23c34f18275bbf23bb716bc7
# 206  0xe4597f9182ba947f7f3bf8cbc6562285751d5aee
# 207  0xf4b6040a4b1b30f1d1691699a8f3bf957b03e463
# 208  0xc0cf5b82ae2352303b2ea02c3be88e23f2594171
#
#     asset.asset_contract.asset_contract_type  asset.asset_contract.owner  \
# 0                               non-fungible                  70753020.0
# 1                               non-fungible                  70006469.0
# 2                               non-fungible                  70753020.0
# 3                               non-fungible                  59376132.0
# 4                               non-fungible                  70753020.0
# ..                                       ...                         ...
# 204                             non-fungible                  25633268.0
# 205                             non-fungible                         NaN
# 206                            semi-fungible                  52705634.0
# 207                             non-fungible                  76721954.0
# 208                             non-fungible                         NaN
#
#     image_id
# 0      0.png
# 1      1.png
# 2      2.png
# 3      3.png
# 4      4.png
# ..       ...
# 204  204.png
# 205  205.png
# 206  206.png
# 207  207.png
# 208  208.png
#
# [209 rows x 14 columns]
