# %% [markdown]
# # Test Library

# %%
from utils import *

pd.options.display.max_columns = 200

# %% [markdown]
# ### 有名collectionのデータ収集
#
# #### 例外発生時の処理について
# - 例外が発生しても処理を続けるように設定している．pramsによってデータ取得時にhttp error 500が発生する可能性が有り，paramを変えないと同様のエラーが発生する．そのときに例外発生し，通常は処理が止まるがデータ収集を効率的にするため処理を続ける．

# %%
collection_df = get_collection_data("data/testA/img", ['cryptopunks', 'boredapeyachtclub', 'doodles-official'])
collection_df
# Out:
# cryptopunks:   0%|          | 0/10 [00:00<?, ?it/s]
# boredapeyachtclub:   0%|          | 0/10 [00:00<?, ?it/s]
# doodles-official:   0%|          | 0/10 [00:00<?, ?it/s]
# error count: 0
# error collection: []
#             id num_sales                                          image_url  \
# 0       526109         1  https://lh3.googleusercontent.com/IKPcUe2aqZ8A...
# 1       530764         7  https://lh3.googleusercontent.com/QZ7ybMm8bN8s...
# 2       526307         1  https://lh3.googleusercontent.com/yEBnoX7de4fS...
# 3       531054         7  https://lh3.googleusercontent.com/dcQT53Sm_j1T...
# 4       527932         6  https://lh3.googleusercontent.com/uKvhp11BMZ5R...
# ...        ...       ...                                                ...
# 1495  74071577         4  https://lh3.googleusercontent.com/mg1xRAVU0OXz...
# 1496  74411947         4  https://lh3.googleusercontent.com/a64kw1dnXk2F...
# 1497  74043129         2  https://lh3.googleusercontent.com/SbXsCW8MaBeK...
# 1498  74043560         5  https://lh3.googleusercontent.com/ISmtGAHUzyWh...
# 1499  74414377         3  https://lh3.googleusercontent.com/2sgNVUry-ceR...
#
#      asset_contract.name                               owner.address  \
# 0            CryptoPunks  0xb98dd602b3f738ff43e2a279a1e74bcbc0f09f61
# 1            CryptoPunks  0x906e55e1035c8a0828f249c173d8090e8fd5f189
# 2            CryptoPunks  0x3be89b64e1437bb18da2d26bcbe9bd3daaadfc26
# 3            CryptoPunks  0x5fe9cfa5cfecdc333eb102d219b4e77eacde9828
# 4            CryptoPunks  0x231e9e1c687fafa53f200e1d7dc042be631777ea
# ...                  ...                                         ...
# 1495             Doodles  0x9f4f1453325fbbf4dabeaeb1cea0a8df1c68ab69
# 1496             Doodles  0x033b16577d125ba2b9d3f270cbae6ac4cfb9b2fb
# 1497             Doodles  0x1b7518d3b45d22595adbe9c3c99f75508dc062de
# 1498             Doodles  0x1d047394a82d08ac977ca5e5aad0ea752c8c7b02
# 1499             Doodles  0xc66916850600ce4aec811b42b9a38cd353cfc63a
#
#      last_sale.quantity  last_sale.total_price  image_id
# 0                     1  140000000000000000000     0.png
# 1                     1  124990000000000000000     1.png
# 2                     1  100000000000000000000     2.png
# 3                     1   94950000000000000000     3.png
# 4                     1   99000000000000000000     4.png
# ...                 ...                    ...       ...
# 1495                  1    1450000000000000000  1495.png
# 1496                  1    1440000000000000000  1496.png
# 1497                  1    1600000000000000000  1497.png
# 1498                  1    1440000000000000000  1498.png
# 1499                  1    1550000000000000000  1499.png
#
# [1500 rows x 8 columns]

# %% [markdown]
# ### 様々なNFTのデータ収集
#
# #### 例外発生時の処理について
# - svgデータでアニメーション付きのものは画像として保存できないため，データから除外する．もし動画データに関しても予測をする場合は要検討．例外が発生した場合でもデータを収集するために処理を続けるようにする．

# %%
random_df = get_random_data("data/testB/img", 5)
random_df
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#              id                                    asset.image_url  \
# 0    1368941488  https://lh3.googleusercontent.com/Fwsygs1eHNU-...
# 1    1368941486  https://lh3.googleusercontent.com/QzD2HcgHl8KF...
# 2    1368941485  https://lh3.googleusercontent.com/3hg1-D7rxnJr...
# 3    1368941483  https://lh3.googleusercontent.com/dmgl6M7qOnpM...
# 4    1368941481  https://lh3.googleusercontent.com/URgqUgJ1H2hY...
# ..          ...                                                ...
# 230  1369007468  https://lh3.googleusercontent.com/YWi0RQtIhPhw...
# 231  1369007467  https://lh3.googleusercontent.com/ZJy9jFJzLrdR...
# 232  1369007465  https://lh3.googleusercontent.com/EzdfVB8UFOhk...
# 233  1369007464  https://storage.opensea.io/files/85c6a8587e44c...
# 234  1369007463  https://lh3.googleusercontent.com/Al8-iYhNkdwm...
#
#                base_price                  current_price  \
# 0      306700000000000000  306700000000000000.0000000000
# 1      710000000000000000  710000000000000000.0000000000
# 2      126500000000000000  126500000000000000.0000000000
# 3      382400000000000000  382400000000000000.0000000000
# 4     4599300000000004500  4599300000000004500.000000000
# ..                    ...                            ...
# 230   5817800000000000000  5817800000000000000.000000000
# 231  32260000000000000000  32260000000000000000.00000000
# 232    115000000000000000  115000000000000000.0000000000
# 233    160000000000000000  160000000000000000.0000000000
# 234    604800000000000000  604800000000000000.0000000000
#
#                                   payment_token quantity asset.num_sales  \
# 0    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               0
# 1    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               0
# 2    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               2
# 3    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               1
# 4    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               0
# ..                                          ...      ...             ...
# 230  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               2
# 231  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               0
# 232  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               0
# 233  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               1
# 234  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2        1               0
#
#      asset.id                             asset.token_id  \
# 0    48446341                                       5372
# 1      932026  15312706511442230855851857334429569515545
# 2    33179399                                       2794
# 3    73689822                                       5339
# 4    47781194                                       1626
# ..        ...                                        ...
# 230  30226450                                       2416
# 231  23134817                                       3432
# 232  29785212                                         79
# 233  49582482                                       4169
# 234  30111183                                       4693
#
#                    asset.asset_contract.address  \
# 0    0xecdd2f733bd20e56865750ebce33f17da0bee461
# 1    0xf87e31492faf9a91b02ee0deaad50d51d56d5d4d
# 2    0x18c7766a10df15df8c971f6e8c1d2bba7c7a410b
# 3    0x5df340b5d1618c543ac81837da1c2d2b17b3b5d8
# 4    0x1cb1a5e65610aeff2551a50f76a87a7d3fb649c6
# ..                                          ...
# 230  0x1a92f7381b9f03921564a437210bb9396471050c
# 231  0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d
# 232  0x984eea281bf65638ac6ed30c4ff7977ea7fe0433
# 233  0x960b7a6bcd451c9968473f7bbfd9be826efd549a
# 234  0x521f9c7505005cfa19a8e5786a9c3c9c9f5e6f42
#
#     asset.asset_contract.asset_contract_type  asset.asset_contract.owner  \
# 0                               non-fungible                  76344085.0
# 1                               non-fungible                     69126.0
# 2                               non-fungible                  50984805.0
# 3                               non-fungible                  93646069.0
# 4                               non-fungible                  76683307.0
# ..                                       ...                         ...
# 230                             non-fungible                  20414503.0
# 231                             non-fungible                  34522873.0
# 232                             non-fungible                  53176133.0
# 233                             non-fungible                  54380779.0
# 234                             non-fungible                  53349452.0
#
#     image_id
# 0      0.png
# 1      1.png
# 2      2.png
# 3      3.png
# 4      4.png
# ..       ...
# 230  230.png
# 231  231.png
# 232  232.png
# 233  233.png
# 234  234.png
#
# [235 rows x 13 columns]
